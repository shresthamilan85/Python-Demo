# %%
#Import excel data in Python using Pandas
import pandas as pd
xl_file = pd.ExcelFile('Sample.xlsx')
college_list = xl_file.parse('College')
college_list.head()
#print(college_list)
# Out:
#    Unnamed: 0  S.N                         Name      OPEID  \
# 0         NaN    1       John Wesley University   293500.0
# 1         NaN    2  Colorado Heights University  3289300.0
# 2         NaN    3    Southern Catholic College  4128500.0
# 3         NaN    4              Vennard College   189400.0
# 4         NaN    5     O'More College of Design  2106401.0
#
#                     Location Geographic Location  \
# 0  High Point,North Carolina           Northeast
# 1           Denver, Colorado                West
# 2       Dawsonville, Georgia               South
# 3      University Park, Iowa             Midwest
# 4               Franklin, TN           Southeast
#
#                                    Enrollment Size  \
# 0           4-year, very small, highly residential
# 1        Four-year, very small, highly residential
# 2                                                8
# 3                                              NaN
# ...

# %%
returns = pd.read_excel('C:\\Users\Milan\Downloads\sample.xlsx')
returns.tail()
# Out:
#     Unnamed: 0  S.N                     Name      OPEID  \
# 64         NaN   65  Sheldon Jackson College   106200.0
# 65         NaN   66   Henry Cogswell College  2291700.0
# 66         NaN   67   Atlantic Union College        NaN
# 67         NaN   68  Kelsey - Jenney College   926800.0
# 68         NaN   69    Wright Career College  2590900.0
#
#                  Location Geographic Location Enrollment Size  \
# 64              Sitka, AK                 NaN             NaN
# 65            Everett, WA                 NaN             NaN
# 66    South Lancaster, MA                 NaN             NaN
# 67  San Diego, California                 NaN             NaN
# 68  Overland Park, Kansas                 NaN             NaN
#
#    Carnegie Classification Religious Affilation  Year Closed Note  \
# 64                     NaN                  NaN         2007  NaN
# 65                     NaN                  NaN         2006  NaN
# ...
